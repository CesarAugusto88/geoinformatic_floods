# %% [markdown]
# # Geoinformática
#   - Cesar Augusto de Moraes Costa
#
# date: 2024/07/08

# %% [markdown]
# # Introduction
#
#
#   - This notebook has been cloned from [remotesensinginfo](https://github.com/remotesensinginfo/rsgislib-tutorials) and is being modified to conform to band images from the Sentinel-2satellite.
#
#
#
# ​
#
# This notebook will go through the steps to undertake a classification using a segmentation rather than a pixel based classification.
#
# ​
#
# A number of studies have proposed that segmenting an image and classifying the segments can produce a better classification result than classifying individual pixels.
#
# ​
#
# The notebook will go through the following steps:
#
# ​
#
#  * Perform segmentation
#
#  * Populate segments with data
#
#  * Extract sample data
#
#  * Split sample data into training, testing and validation sets
#
#  * Training Classifier
#
#  * Apply Classifier
#
# ​

# %% [markdown]
# ## Running Notebook
#
# The notebook has been run and saved with the outputs so you can see what the outputs should be and so the notebook and be browsed online without having to run the notebook for it to make sense.
#
# If you are running the notebook for yourself it is recommended that you clear the existing outputs which can be done by running one of the following options depending on what system you are using:
#
# **Jupyter-lab**:
#
# > \> _Edit_ \> _'Clear All Outputs'_
#
# **Jupyter-notebook**:
#
# > \> _Cell_ \> _'All Outputs'_ \> _Clear_

# %%
from platform import python_version

print(python_version())
# Out:
# 3.10.14

# %% [markdown]
# # 1. Import the modules needed

# %%
# Import modules from python standard library
import os
import pprint
import random

# Import the matplotlib plotting module and set it to work within
# a notebook environment.
# %matplotlib inline
import matplotlib
import matplotlib.colors as mcolors
import matplotlib.pyplot as plt

# Import the RSGISLib modules for the notebook
import rsgislib
from rsgislib.segmentation import shepherdseg
import rsgislib.classification
import rsgislib.classification.classsklearn
import rsgislib.classification.classratutils
import rsgislib.classification.classaccuracymetrics
import rsgislib.tools.filetools
import rsgislib.tools.plotting
import rsgislib.vectorutils
import rsgislib.zonalstats
import rsgislib.rastergis
import rsgislib.vectorutils.createrasters
from sklearn.ensemble import RandomForestClassifier

# Import the geopandas module
import geopandas

# Import the numpy module
import numpy

# scikit-learn imports
from sklearn.model_selection import GridSearchCV
# import tensorflow as tf

# %%
import rasterio
import matplotlib.pyplot as plt
import numpy as np


img_concat_array = rasterio.open('raster_out_concatenate_t2_t1.jp2').read()
# plt.figure(figsize=(10, 10))
# plt.imshow(img_concat_array[0,:,:]);
# Stack RGB NIR - 8 channels
img_concat_array = np.stack([img_concat_array[0],img_concat_array[1],
                  img_concat_array[2]], axis=2)
# img_concat_array = np.stack(img_concat_array, axis=2)
# img_concat_array = np.dstack(img_concat_array)

print(img_concat_array.shape)

concat_t2_t1 = img_concat_array / img_concat_array.max()
plt.figure(figsize=(15, 10))
plt.imshow(concat_t2_t1*3)
# Out:
# (10980, 10980, 3)
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).

# %% [markdown]
# # 2. Define the input image

# %%
# Input Sentinel-2 image file with 20 m resolution pixels.  # MUX
input_img = "./raster_out_concatenate_t2_t1.jp2"
img_band_info = list()
img_band_info.append(
    rsgislib.imageutils.ImageBandInfo(
        file_name=input_img, name="sen2", bands=[1,2,3,4,5,6,7,8]
    )
)

# %% [markdown]
# # 3. Perform Segmentation
#
# This segmentation is trying to group neighbouring pixels which are of the same class together in an unsupervised process to simplify and improve following classification steps. In some cases these kind of segments (also referred to as clumps) can be referred to as 'super-pixels' (i.e., larger grouping of image pixels with similar properties.
#
# One advantage of having a group of pixels is that is allows some statistic properties of groups (e.g., standard deviation) to be calculated alongside a simple mean which can be useful when trying to classify classes which have a changing texture of time, for example.
#
# However, you should also bear in mind that the boundaries drawn by the segmentation will then be the boundaries within final map so any errors within the segmentation might be brought through into the classification result.

# %%
clumps_img = "sentinel2_20240506_RS_segs.kea"
tmp_dir = "tmp"

shepherdseg.run_shepherd_segmentation(
    input_img,
    clumps_img,
    None,
    tmp_dir,
    gdalformat="KEA", # Output file format
    calc_stats=True,  # Calculate statistics on the output images
    no_stretch=False, # Normalise the input bands by applying a 2 standard devation stretch
    no_delete=False,  # Delete the temporary files created during the processing
    num_clusters=60,  # The number of clusters (k) for the initial kMeans clustering
    min_n_pxls=50,    # Minimum number of pixels within a clump (segment). 50 -> 70...
    dist_thres=100,
    bands=[1,2,3,4,5,6,7,8],  # Just use bands 8 (NIR), 9 (SWIR) and 3 (Red)
    sampling=100,     # Speed up the kMeans clustering by only using every 100th pixel.
    km_max_iter=200,  # Maximum number of kMeans iterations
    process_in_mem=True,  # Do the process using in-memory datasets rather than to disk
    save_process_stats=False,
    img_stretch_stats="",
    kmeans_centres="",
    img_stats_json_file="",
)
# Out:
# Subsetting the image bands
# New image width = 10980 height = 10980 bands = 8
# Stretch Input Image
#
#
#
# Band[1] Min = 0 Mean = 21.3023134138 (Std Dev = 13.7287600174) max = 255
# Band[2] Min = 0 Mean = 19.9772524526 (Std Dev = 12.5097531952) max = 255
# Band[3] Min = 0 Mean = 17.1865250807 (Std Dev = 11.529081974) max = 255
# Band[4] Min = 0 Mean = 39.1290448297 (Std Dev = 24.2256015395) max = 255
# Band[5] Min = 0 Mean = 19.1834539054 (Std Dev = 12.7054529374) max = 255
# Band[6] Min = 0 Mean = 19.2846258198 (Std Dev = 11.4498395189) max = 255
# Band[7] Min = 0 Mean = 15.541556464 (Std Dev = 9.3832996275) max = 255
# Band[8] Min = 0 Mean = 46.3623828157 (Std Dev = 27.528559463) max = 255
# New image width = 10980 height = 10980 bands = 8
#
# Add 1 to stretched file to ensure there are no all zeros (i.e., no data) regions created.
# Create Input Image Mask.
# New image width = 10980 height = 10980 bands = 8
# Mask stretched Image.
#
# Image: tmp/raster_out_concatenate_t2_t1_bselect.kea
# 	 Variable 'b1' is band 1
# New image width = 10980 height = 10980 bands = 1
#
# New image width = 10980 height = 10980 bands = 8
#
# Deleting file: tmp/raster_out_concatenate_t2_t1_stchdonly.kea
# Deleting file: tmp/raster_out_concatenate_t2_t1_stchdonly_off.kea
# Deleting file: tmp/raster_out_concatenate_t2_t1_stchdmaskonly.kea
# Performing KMeans.
# Apply KMeans to image.
# inputImage = tmp/raster_out_concatenate_t2_t1_stchd.kea
# outputMatrixFile = tmp/raster_out_concatenate_t2_t1_kmeansclusters
# numClusters = 60
# maxNumIterations = 200
# subSample = 100
# degreeOfChange = 0.00249999994412
# Ignoring Zeros
# Full diag attached.
# Subsampling the image to read into memory
# Performing clustering
# Starting Iterative processing...
# Iteration 0 has change 39.077911377 % of data clump IDs (60 clusters).
# Iteration 1 has change 17.2226676941 % of data clump IDs (60 clusters).
# Iteration 2 has change 13.3770971298 % of data clump IDs (60 clusters).
# Iteration 3 has change 12.2315187454 % of data clump IDs (60 clusters).
# Iteration 4 has change 10.3162136078 % of data clump IDs (60 clusters).
# Iteration 5 has change 8.0470790863 % of data clump IDs (60 clusters).
# Iteration 6 has change 6.95955896378 % of data clump IDs (60 clusters).
# Iteration 7 has change 6.33682441711 % of data clump IDs (60 clusters).
# Iteration 8 has change 5.72620725632 % of data clump IDs (60 clusters).
# Iteration 9 has change 5.10779333115 % of data clump IDs (60 clusters).
# Iteration 10 has change 4.59106063843 % of data clump IDs (60 clusters).
# Iteration 11 has change 4.1712679863 % of data clump IDs (60 clusters).
# Iteration 12 has change 3.78171610832 % of data clump IDs (60 clusters).
# Iteration 13 has change 3.43937015533 % of data clump IDs (60 clusters).
# Iteration 14 has change 3.19396448135 % of data clump IDs (60 clusters).
# Iteration 15 has change 2.98259305954 % of data clump IDs (60 clusters).
# Iteration 16 has change 2.71221446991 % of data clump IDs (60 clusters).
# Iteration 17 has change 2.53298068047 % of data clump IDs (60 clusters).
# Iteration 18 has change 2.41201639175 % of data clump IDs (60 clusters).
# Iteration 19 has change 2.30085134506 % of data clump IDs (60 clusters).
# Iteration 20 has change 2.18115139008 % of data clump IDs (60 clusters).
# Iteration 21 has change 2.08442211151 % of data clump IDs (60 clusters).
# Iteration 22 has change 1.99338269234 % of data clump IDs (60 clusters).
# Iteration 23 has change 1.89633738995 % of data clump IDs (60 clusters).
# Iteration 24 has change 1.82869005203 % of data clump IDs (60 clusters).
# Iteration 25 has change 1.80287456512 % of data clump IDs (60 clusters).
# Iteration 26 has change 1.74397289753 % of data clump IDs (60 clusters).
# Iteration 27 has change 1.68338525295 % of data clump IDs (60 clusters).
# Iteration 28 has change 1.6353366375 % of data clump IDs (60 clusters).
# Iteration 29 has change 1.54556179047 % of data clump IDs (60 clusters).
# Iteration 30 has change 1.46590232849 % of data clump IDs (60 clusters).
# Iteration 31 has change 1.38276576996 % of data clump IDs (60 clusters).
# Iteration 32 has change 1.25442552567 % of data clump IDs (60 clusters).
# Iteration 33 has change 1.20932734013 % of data clump IDs (60 clusters).
# Iteration 34 has change 1.22376298904 % of data clump IDs (60 clusters).
# Iteration 35 has change 1.22018039227 % of data clump IDs (60 clusters).
# Iteration 36 has change 1.19942259789 % of data clump IDs (60 clusters).
# Iteration 37 has change 1.18540847301 % of data clump IDs (60 clusters).
# Iteration 38 has change 1.12703359127 % of data clump IDs (60 clusters).
# Iteration 39 has change 1.107224226Eliminate Single Pixels.
# Perform clump.
# Eliminate small pixels.
# Relabel clumps.
#  % of data clump IDs (60 clusters).
# Iteration 40 has change 1.05527698994 % of data clump IDs (60 clusters).
# Iteration 41 has change 0.986259818077 % of data clump IDs (60 clusters).
# Iteration 42 has change 0.969716727734 % of data clump IDs (60 clusters).
# Iteration 43 has change 0.946640789509 % of data clump IDs (60 clusters).
# Iteration 44 has change 0.959811985493 % of data clump IDs (60 clusters).
# Iteration 45 has change 1.00448870659 % of data clump IDs (60 clusters).
# Iteration 46 has change 1.05696284771 % of data clump IDs (60 clusters).
# Iteration 47 has change 1.0331492424 % of data clump IDs (60 clusters).
# Iteration 48 has change 0.973088562489 % of data clump IDs (60 clusters).
# Iteration 49 has change 0.907548725605 % of data clump IDs (60 clusters).
# Iteration 50 has change 0.86887806654 % of data clump IDs (60 clusters).
# Iteration 51 has change 0.835581243038 % of data clump IDs (60 clusters).
# Iteration 52 has change 0.819248914719 % of data clump IDs (60 clusters).
# Iteration 53 has change 0.784898459911 % of data clump IDs (60 clusters).
# Iteration 54 has change 0.734637141228 % of data clump IDs (60 clusters).
# Iteration 55 has change 0.697968482971 % of data clump IDs (60 clusters).
# Iteration 56 has change 0.675208628178 % of data clump IDs (60 clusters).
# Iteration 57 has change 0.630953371525 % of data clump IDs (60 clusters).
# Iteration 58 has change 0.593020319939 % of data clump IDs (60 clusters).
# Iteration 59 has change 0.554455041885 % of data clump IDs (60 clusters).
# Iteration 60 has change 0.518102526665 % of data clump IDs (60 clusters).
# Iteration 61 has change 0.482487589121 % of data clump IDs (60 clusters).
# Iteration 62 has change 0.449612230062 % of data clump IDs (60 clusters).
# Iteration 63 has change 0.431277930737 % of data clump IDs (60 clusters).
# Iteration 64 has change 0.412416726351 % of data clump IDs (60 clusters).
# Iteration 65 has change 0.385231375694 % of data clump IDs (60 clusters).
# Iteration 66 has change 0.355727910995 % of daCalculate image statistics and build pyramids.
# ta clump IDs (60 clusters).
# Iteration 67 has change 0.346349984407 % of data clump IDs (60 clusters).
# Iteration 68 has change 0.330755293369 % of data clump IDs (60 clusters).
# Iteration 69 has change 0.308627665043 % of data clump IDs (60 clusters).
# Iteration 70 has change 0.299881994724 % of data clump IDs (60 clusters).
# Iteration 71 has change 0.296615540981 % of data clump IDs (60 clusters).
# Iteration 72 has change 0.281126201153 % of data clump IDs (60 clusters).
# Iteration 73 has change 0.258893191814 % of data clump IDs (60 clusters).
# Iteration 74 has change 0.249304547906 % of data clump IDs (60 clusters).
# Exporting cluster centres to output file
# New image width = 10980 height = 10980 bands = 1
#
# Eliminating Individual Pixels
#
# There are 4674656 single pixels within the image
#
#
# There are 53389 single pixels within the image
#
#
# There are 1016 single pixels within the image
#
#
# There are 764 single pixels within the image
#
# Complete, all connected single pixels have been removed
# Processing in Memory
# Performing Clump
#
#
# (Generated 3935567 clumps).
# Copying output to disk
# Processing in Memory
# Eliminant Clumps
# Calc Number of clumps
#
# Build clump table
# Calculate Initial Clump Means
# There are 3935567 clumps.
# Eliminating Small Clumps.
# Eliminating clumps of size 1
# Found 764 small clumps to be eliminated.
# Eliminated 764 small clumps
# Eliminating clumps of size 2
# Found 948840 small clumps to be eliminated.
# Eliminated 949604 small clumps
# Eliminating clumps of size 3
# Found 586331 small clumps to be eliminated.
# Eliminated 1535935 small clumps
# Eliminating clumps of size 4
# Found 367418 small clumps to be eliminated.
# Eliminated 1903353 small clumps
# Eliminating clumps of size 5
# Found 287291 small clumps to be eliminated.
# Eliminated 2190644 small clumps
# Eliminating clumps of size 6
# Found 202512 small clumps to be eliminated.
# Eliminated 2393156 small clumps
# Eliminating clumps of size 7
# Found 178620 small clumps to be eliminated.
# Eliminated 2571776 small clumps
# Eliminating clumps of size 8
# Found 144566 small clumps to be eliminated.
# Eliminated 2716342 small clumps
# Eliminating clumps of size 9
# Found 130554 small clumps to be eliminated.
# Eliminated 2846896 small clumps
# Eliminating clumps of size 10
# Found 108693 small clumps to be eliminated.
# Eliminated 2955589 small clumps
# Eliminating clumps of size 11
# Found 103380 small clumps to be eliminated.
# Eliminated 3058969 small clumps
# Eliminating clumps of size 12
# Found 90036 small clumps to be eliminated.
# Eliminated 3149005 small clumps
# Eliminating clumps of size 13
# Found 85744 small clumps to be eliminated.
# Eliminated 3234749 small clumps
# Eliminating clumps of size 14
# Found 76932 small clumps to be eliminated.
# Eliminated 3311681 small clumps
# Eliminating clumps of size 15
# Found 74780 small clumps to be eliminated.
# Eliminated 3386461 small clumps
# Eliminating clumps of size 16
# Found 68378 small clumps to be eliminated.
# Eliminated 3454839 small clumps
# Eliminating clumps of size 17
# Found 66849 small clumps to be eliminated.
# Eliminated 3521688 small clumps
# Eliminating clumps of size 18
# Found 61854 small clumps to be eliminated.
# Eliminated 3583542 small clumps
# Eliminating clumps of size 19
# Found 60825 small clumps to be eliminated.
# Eliminated 3644367 small clumps
# Eliminating clumps of size 20
# Found 57817 small clumps to be eliminated.
# Eliminated 3702184 small clumps
# Eliminating clumps of size 21
# Found 56475 small clumps to be eliminated.
# Eliminated 3758659 small clumps
# Eliminating clumps of size 22
# Found 54016 small clumps to be eliminated.
# Eliminated 3812675 small clumps
# Eliminating clumps of size 23
# Found 53409 small clumps to be eliminated.
# Eliminated 3866084 small clumps
# Eliminating clumps of size 24
# Found 51351 small clumps to be eliminated.
# Eliminated 3917435 small clumps
# Eliminating clumps of size 25
# Found 50760 small clumps to be eliminated.
# Eliminated 3968195 small clumps
# Eliminating clumps of size 26
# Found 48850 small clumps to be eliminated.
# Eliminated 4017045 small clumps
# Eliminating clumps of size 27
# Found 48477 small clumps to be eliminated.
# Eliminated 4065522 small clumps
# Eliminating clumps of size 28
# Found 47080 small clumps to be eliminated.
# Eliminated 4112602 small clumps
# Eliminating clumps of size 29
# Found 46685 small clumps to be eliminated.
# Eliminated 4159287 small clumps
# Eliminating clumps of size 30
# Found 45539 small clumps to be eliminated.
# Eliminated 4204826 small clumps
# Eliminating clumps of size 31
# Found 45548 small clumps to be eliminated.
# Eliminated 4250374 small clumps
# Eliminating clumps of size 32
# Found 44362 small clumps to be eliminated.
# Eliminated 4294736 small clumps
# Eliminating clumps of size 33
# Found 44180 small clumps to be eliminated.
# Eliminated 4338916 small clumps
# Eliminating clumps of size 34
# Found 43368 small clumps to be eliminated.
# Eliminated 4382284 small clumps
# Eliminating clumps of size 35
# Found 43288 small clumps to be eliminated.
# Eliminated 4425572 small clumps
# Eliminating clumps of size 36
# Found 42711 small clumps to be eliminated.
# Eliminated 4468283 small clumps
# Eliminating clumps of size 37
# Found 42292 small clumps to be eliminated.
# Eliminated 4510575 small clumps
# Eliminating clumps of size 38
# Found 41848 small clumps to be eliminated.
# Eliminated 4552423 small clumps
# Eliminating clumps of size 39
# Found 41627 small clumps to be eliminated.
# Eliminated 4594050 small clumps
# Eliminating clumps of size 40
# Found 41127 small clumps to be eliminated.
# Eliminated 4635177 small clumps
# Eliminating clumps of size 41
# Found 41015 small clumps to be eliminated.
# Eliminated 4676192 small clumps
# Eliminating clumps of size 42
# Found 40393 small clumps to be eliminated.
# Eliminated 4716585 small clumps
# Eliminating clumps of size 43
# Found 40536 small clumps to be eliminated.
# Eliminated 4757121 small clumps
# Eliminating clumps of size 44
# Found 40099 small clumps to be eliminated.
# Eliminated 4797220 small clumps
# Eliminating clumps of size 45
# Found 40078 small clumps to be eliminated.
# Eliminated 4837298 small clumps
# Eliminating clumps of size 46
# Found 3Deleting file: tmp/raster_out_concatenate_t2_t1_kmeansclusters.gmtxt
# 9712 small clumps to be eliminated.
# Eliminated 4877010 small clumps
# Eliminating clumps of size 47
# Found 39544 small clumps to be eliminated.
# Eliminated 4916554 small clumps
# Eliminating clumps of size 48
# Found 39231 small clumps to be eliminated.
# Eliminated 4955785 small clumps
# Eliminating clumps of size 49
# Found 39190 small clumps to be eliminated.
# Eliminated 4994975 small clumps
# Eliminating clumps of size 50
# Found 38890 small clumps to be eliminated.
# Eliminated 5033865 small clumps
# Finshed Elimination. 5033865 small clumps eliminated
# Copying output to disk
# Opening clumps file: tmp/raster_out_concatenate_t2_t1_clumps_elim.kea
# Processing in Memory
# Performing relabel
# Finding maximum image value
#
# Creating Look up table.
#
# Applying Look up table.
#
# Copying output to disk
# Get Image Min and Max.
#
# Get Image Histogram.
#
# Adding Histogram and Colour Table to image file
# Calculating Image Pyramids.
#
# Deleting file: tmp/raster_out_concatenate_t2_t1_kmeans.kea.aux.xml
# Deleting file: tmp/raster_out_concatenate_t2_t1_kmeans.kea
# Deleting file: tmp/raster_out_concatenate_t2_t1_kmeans_nosgl.kea
# Deleting file: tmp/raster_out_concatenate_t2_t1_clumps.kea
# Deleting file: tmp/raster_out_concatenate_t2_t1_clumps_elim.kea
# Deleting file: tmp/raster_out_concatenate_t2_t1_bselect.kea
# Deleting file: tmp/raster_out_concatenate_t2_t1_stchd.kea

# %% [markdown]
# # 4. Create Vector Polygons for the Clumps
#
# While the raster clumps provide an efficient way of storing and processing the segments when visualising the segments within a GIS having a raster version can also be helpful. The command below show how to vectorise the segments to a vector layer. You will probably find it useful to open the layer produced, alongside the input image, with QGIS to visualise the segmentation.
#
# While raster clumps are efficient when dealing with raster data of the same spatial resolution as the clump pixels, when dealing with data at very different resolutions (e.g., segments from landsat intersecting with MODIS pixels) it can also be useful to use a vector and zonal statistics for further data analysis where the raster datasets do not have to be resampled to the same resolution as the raster clumps.

# %%
import rsgislib.vectorutils.createvectors

segs_vec_file = "sentinel2_20240506_RS_segs.gpkg"
segs_vec_lyr = "sentinel2_20240506_RS_segs.kea"

rsgislib.vectorutils.createvectors.polygonise_raster_to_vec_lyr(
    out_vec_file=segs_vec_file,   # The output vector file name and path
    out_vec_lyr=segs_vec_lyr,     # The output vector layer name
    out_format="GPKG",            # The output vector format
    input_img=clumps_img,         # The input segmentation image
    img_band=1,                   # The band within the input image
    mask_img=clumps_img,          # A mask image (usually the same as the input image)
    mask_band=1,                  # The band within the mask image
)
# Out:
#   0%|                                                                                                                 | 0/100 [00:00<?, ?it/s]
# Polygonising...
# 101it [00:20,  8.16it/s]
# Completed
# 101it [00:20,  4.82it/s]

# %% [markdown]
# # 5. Visualise Segmentation

# %%
# Get the full image bounding box.
img_bbox = rsgislib.imageutils.get_img_bbox(input_img)
print(img_bbox, img_bbox[0])
# Out:
# [399960.0, 509760.0, 6590200.0, 6700000.0] 399960.0

# %%
# Define a bbox for the subset to be displayed - troca posição 2 com 3
sub_img_bbox = [399960.0, 6590200.0, 509760.0, 6700000.0]
# Subset bbox reformated for geopandas
gp_img_bbox = (sub_img_bbox[0], sub_img_bbox[2], sub_img_bbox[1], sub_img_bbox[3])

# Use geopandas to read the vector layer
segs_gdf = geopandas.read_file(segs_vec_file, layer=segs_vec_lyr, bbox=gp_img_bbox)

### Input image
# Get the image data as a numpy array and the spatial bounding
# box of the image data. We have specified that the bands we
# want for the visualisation are 8, 9, 3 (NIR, SWIR1, Red)
# which produces a good false colour visualisation which is
# good at picking out vegetation. If you want a true colour
# (i.e., Red, Green, Blue) visualisation change the bands to
# [3, 2, 1]
img_data, img_coords = rsgislib.tools.plotting.get_gdal_raster_mpl_imshow(
    input_img, bands=[1, 2, 3], bbox=sub_img_bbox,
)

# Stretch the image data so is visualises appropriately and usefully
# In this case the resulting values will be between 0-1.
img_data_strch = rsgislib.tools.plotting.stdev_stretch_np_arr(img_data, no_data_val=0.0)

# Create the matplotlib figure - in this case two plots so the NDVI
# and image are plotted alongside each other
fig, (ax1, ax2) = plt.subplots(1, 2, figsize=(16, 8), sharey=True)

# Use the imshow function to display the image data within the plot
# the extent option defines the x and y axis values.
ax1.imshow(img_data_strch, extent=img_coords)
ax1.title.set_text("Input Image")

# Plot the polygons with no face colour and an edge colour of yellow. 
# i.e., just the polygon outlines in yellow.
segs_gdf.plot(ax=ax2, facecolor="none", edgecolor="yellow")
ax2.imshow(img_data_strch, extent=img_coords)
ax2.title.set_text("Segmentation Output")
# Out:
# Image Data Size: 10980 x 10980

# %% [markdown]
# # 6. Compare Clusters with Segments

# %%
# Compare cluterizers with segments
import rsgislib.classification.clustersklearn
import rsgislib.tools.plotting

from sklearn.cluster import MiniBatchKMeans

# %%
# Define the number of output classes/clusters as 10.
clusterer = MiniBatchKMeans(batch_size=100, n_clusters=10)

# %%
out_cls_img_kmeans = "sentinel2_kmeans_cls.kea"
rsgislib.classification.clustersklearn.img_pixel_sample_cluster(
    input_img,
    out_cls_img_kmeans,
    gdalformat="KEA",
    no_data_val=0,
    n_img_smpl=100,
    clusterer=clusterer,
    calc_stats=True,
    use_mean_shift_est_band_width=False,
)
# Out:
# Sample Input Image:
#   0%|          | 0/100 [00:00<?, ?it/s]
# Fit Clusterer
# Fitted Clusterer
# Applying to Whole Image
#   0%|          | 0/100 [00:00<?, ?it/s]
# Get Image Min and Max.
#
# Get Image Histogram.
#
# Adding Histogram and Colour Table to image file
# Calculating Image Pyramids.

# %%
# Define a bbox for the subset to be displayed
sub_img_bbox = [405940.0, 6734770.0, 407960.0, 6736790.0]
# Subset bbox reformated for geopandas
gp_img_bbox = (sub_img_bbox[0], sub_img_bbox[2], sub_img_bbox[1], sub_img_bbox[3])

# Use geopandas to read the vector layer
segs_gdf = geopandas.read_file(segs_vec_file, layer=segs_vec_lyr, bbox=gp_img_bbox)

### Input image
# Get the image data as a numpy array and the spatial bounding
# box of the image data. We have specified that the bands we
# want for the visualisation are 8, 9, 3 (NIR, SWIR1, Red)
# which produces a good false colour visualisation which is
# good at picking out vegetation. If you want a true colour
# (i.e., Red, Green, Blue) visualisation change the bands to
# [3, 2, 1]
img_data, img_coords = rsgislib.tools.plotting.get_gdal_raster_mpl_imshow(
    input_img, bands=[1, 2, 3], bbox=sub_img_bbox,
)

# Stretch the image data so is visualises appropriately and usefully
# In this case the resulting values will be between 0-1.
img_data_strch = rsgislib.tools.plotting.stdev_stretch_np_arr(img_data, no_data_val=0.0)

# Create the matplotlib figure - in this case two plots so the NDVI
# and image are plotted alongside each other
fig, (ax1, ax2) = plt.subplots(1, 2, figsize=(16, 8), sharey=True)

# Plot the polygons with no face colour and an edge colour of yellow. 
# i.e., just the polygon outlines in yellow.
segs_gdf.plot(ax=ax1, facecolor="none", edgecolor="yellow")
ax1.imshow(img_data_strch, extent=img_coords)
ax1.title.set_text("Segmentation Result")

# Get the image data using the get_gdal_thematic_raster_mpl_imshow function.
(
    img_cls_data,
    img_cls_coords,
    lgd_patches,
) = rsgislib.tools.plotting.get_gdal_thematic_raster_mpl_imshow(
    out_cls_img_kmeans, out_patches=False, bbox=sub_img_bbox
)

ax2.imshow(img_cls_data, extent=img_cls_coords)
ax2.title.set_text("KMeans Clustering Result")
# Out:
# Image Data Size: 202 x 202
# Image Data Size: 202 x 202

# %%
from sklearn.cluster import MeanShift

clusterer = MeanShift()

out_cls_img_meanshift = "sentinel2_meanshift_cls.kea"
rsgislib.classification.clustersklearn.img_pixel_sample_cluster(
    input_img,
    out_cls_img_meanshift,
    gdalformat="KEA",
    no_data_val=0,
    n_img_smpl=100,
    clusterer=clusterer,
    calc_stats=True,
    use_mean_shift_est_band_width=True,
)
# Out:
# Sample Input Image:
#   0%|          | 0/100 [00:00<?, ?it/s]
# Using Mean-Shift predict bandwidth
# Fit Clusterer
# Fitted Clusterer
# Applying to Whole Image
#   0%|          | 0/100 [00:00<?, ?it/s]
# Get Image Min and Max.
#
# Get Image Histogram.
#
# Adding Histogram and Colour Table to image file
# Calculating Image Pyramids.

# %%
# Define a bbox for the subset to be displayed
sub_img_bbox = [405940.0, 6734770.0, 407960.0, 6736790.0]
# Subset bbox reformated for geopandas
gp_img_bbox = (sub_img_bbox[0], sub_img_bbox[2], sub_img_bbox[1], sub_img_bbox[3])
# Use geopandas to read the vector layer
segs_gdf = geopandas.read_file(segs_vec_file, layer=segs_vec_lyr, bbox=gp_img_bbox)

### Input image
# Get the image data as a numpy array and the spatial bounding
# box of the image data. We have specified that the bands we
# want for the visualisation are 8, 9, 3 (NIR, SWIR1, Red)
# which produces a good false colour visualisation which is
# good at picking out vegetation. If you want a true colour
# (i.e., Red, Green, Blue) visualisation change the bands to
# [3, 2, 1]
img_data, img_coords = rsgislib.tools.plotting.get_gdal_raster_mpl_imshow(
    input_img, bands=[1, 2, 3], bbox=sub_img_bbox,
)

# Stretch the image data so is visualises appropriately and usefully
# In this case the resulting values will be between 0-1.
img_data_strch = rsgislib.tools.plotting.stdev_stretch_np_arr(img_data, no_data_val=0.0)

# Create the matplotlib figure - in this case two plots so the NDVI
# and image are plotted alongside each other
fig, (ax1, ax2) = plt.subplots(1, 2, figsize=(16, 8), sharey=True)

# Use the imshow function to display the image data within the plot
# the extent option defines the x and y axis values.
# ax1.imshow(img_data_strch, extent=img_coords)
# ax1.title.set_text("Input Image")

# Plot the polygons with no face colour and an edge colour of yellow. 
# i.e., just the polygon outlines in yellow.
segs_gdf.plot(ax=ax1, facecolor="none", edgecolor="yellow")
ax1.imshow(img_data_strch, extent=img_coords)
ax1.title.set_text("Segmentation Result")

# Get the image data using the get_gdal_thematic_raster_mpl_imshow function.
(
    img_cls_data,
    img_cls_coords,
    lgd_patches,
) = rsgislib.tools.plotting.get_gdal_thematic_raster_mpl_imshow(
    out_cls_img_meanshift, out_patches=False, bbox=sub_img_bbox
)
ax2.imshow(img_cls_data, extent=img_cls_coords)
ax2.title.set_text("Mean-Shift Clustering Result")
# Out:
# Image Data Size: 202 x 202
# Image Data Size: 202 x 202

# %% [markdown]
# ## Referece:
#   - Remote Sensing Info. Software tools written support spatial data analysis. [GitHub](https://github.com/remotesensinginfo/rsgislib-tutorials/blob/main/03_intro_image_classification/02_segment_ml_classification.ipynb)
